# %% [markdown]
# <a href="https://colab.research.google.com/github/vtecftwy/utseus-dives/blob/main/nbs/dive_4.2_rag_w_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retrieval Augmented Generation

# %% [markdown]
# RAG using Langchain package.
#
# Inspired by LangChain RAG tutorial [here](https://docs.langchain.com/oss/python/langchain/rag)

# %% [markdown]
# ## 0. Installs, Imports, Utility Fctn and Setup

# %%
import faiss
import os
import textwrap
from dotenv import load_dotenv
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_openai import OpenAIEmbeddings
from pathlib import Path
from pprint import pprint

# %%
def show_attr(o):
    for a in o.__dict__:
        if not '_' in a:
            print(f"{a:10s}: \t{getattr(o, a)}")

def printmd(*txt):
    for t in txt:
        display(Markdown(t))

def setup_clean_proxy():
    """Clear problematic proxy vars and set clean ones"""
    env_backup = {}
    proxy_vars = ['http_proxy', 'https_proxy', 'HTTP_PROXY', 'HTTPS_PROXY', 'no_proxy', 'NO_PROXY']
    for var in proxy_vars:
        if var in os.environ:
            env_backup[var] = os.environ[var]
            del os.environ[var]
    
    os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:16005'
    os.environ['HTTP_PROXY'] = 'http://127.0.0.1:16005'
    return env_backup

# Call at start
env_backup = setup_clean_proxy()

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Step 1: Indexing the knowledge base

# %% [markdown]
# 1. Load: :Load our data. This is done with Document Loaders. We load all files we want in our knowledge base
# 2. Split: Text splitters break large Documents into smaller chunks. This is useful both for indexing data and passing it into a model, as large chunks are harder to search over and won’t fit in a model’s finite context window.
# 3. Store: We need somewhere to store and index our splits, so that they can be searched over later. This is often done using a VectorStore and Embeddings model.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Loading pdf documents

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
p2docs = Path('data')
assert p2docs.is_dir()

# %%
files = [f for f in p2docs.iterdir() if f.suffix.lower() == '.pdf']
print('List of files:')
for f in files:
    print(f"- {f.name}")
# Out:
# List of files:
# - Brynjolfsson et al. - 2025 - Generative AI at Work.pdf
# - Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf
# - McK - One year of agentic ai six lessons from the people doing the work (2025).pdf

# %% [markdown]
# Let's load the first file

# %%
file_path = files[1]
print(file_path.name)
loader = PyPDFLoader(
    file_path,
    mode="single"
    )
# Out:
# Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf

# %% [markdown]
# The loader will load the split the file in several chunks

# %%
docs = loader.load()
len(docs)
# Out:
# 1

# %%
show_attr(docs[0])
# Out:
# id        : 	None
# metadata  : 	{'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23}
# type      : 	Document

# %%
pprint(docs[0].metadata)
# Out:
# {'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank '
#            'Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca '
#            'Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.',
#  'creationdate': '2025-08-01T12:04:28-07:00',
#  'creator': 'LaTeX with hyperref',
#  'keywords': '',
#  'moddate': '2025-08-01T12:04:28-07:00',
#  'producer': 'pdfTeX-1.40.22',
#  'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live '
#                     '2021) kpathsea version 6.3.3',
#  'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf',
#  'subject': '',
#  'title': 'Tracking Employment Changes in AI-Exposed Jobs',
#  'total_pages': 23,
#  'trapped': '/False'}

# %%
print(docs[0].page_content[:2000])
# Out:
# Tracking Employment Changes in AI-Exposed Jobs
# Bharat Chandar∗
# August 1, 2025
# Abstract
# This paper examines labor market trends for occupations exposed to Generative AI
# using US Current Population Survey (CPS) data from the post-ChatGPT era (Q4 2022
# - Q1 2025). Contrary to displacement fears, occupations most exposed to AI on average
# show no substantial diﬀerence in employment or earnings growth compared to the
# least exposed. However, this aggregate trend masks heterogeneity across occupations.
# Within the most exposed quartile, occupations with a higher share of college-educated
# workers, such as software development, have experienced robust employment growth,
# while those with a lower share, like customer service, have seen declines. The analysis
# also reveals a divergence between job posting data and realized employment, urging
# caution when inferring labor market trends from postings alone.
# 1 Introduction
# The period following the public release of ChatGPT in November 2022 has seen burgeoning
# research attempting to capture the labor market and productivity eﬀects of generative AI,
# spurred by fear of potential widespread job displacement. This paper provides a timely
# empirical analysis of this evolving landscape by leveraging U.S. Current Population Survey
# ∗Stanford University;chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Tram-
# mell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.
# 1
# (CPS) data through Q1 2025. Using the GPT-4-based occupational exposure metrics from
# Eloundou et al. (2024), I examine realized employment and earnings trends to measure
# whether, and how, disruption from new AI technologies is appearing in the U.S. workforce.
# The central ﬁnding is that the most AI-exposed set of occupations has not experienced a
# declining share of employment, though among this group there is considerable heterogeneity
# in labor market trends. Software occupations, which are estimated to have high exposure to
# generative AI, show

# %% [markdown]
# ### Splitting document

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(docs)

print(f"Split file content into {len(all_splits)} sub-documents.")
# Out:
# Split file content into 41 sub-documents.

# %%
for i,s in enumerate(all_splits[:5]):
    print(f'>>> Split {i+1} ------------')
    print(s.page_content)
    print()
# Out:
# >>> Split 1 ------------
# Tracking Employment Changes in AI-Exposed Jobs
# Bharat Chandar∗
# August 1, 2025
# Abstract
# This paper examines labor market trends for occupations exposed to Generative AI
# using US Current Population Survey (CPS) data from the post-ChatGPT era (Q4 2022
# - Q1 2025). Contrary to displacement fears, occupations most exposed to AI on average
# show no substantial diﬀerence in employment or earnings growth compared to the
# least exposed. However, this aggregate trend masks heterogeneity across occupations.
# Within the most exposed quartile, occupations with a higher share of college-educated
# workers, such as software development, have experienced robust employment growth,
# while those with a lower share, like customer service, have seen declines. The analysis
# also reveals a divergence between job posting data and realized employment, urging
# caution when inferring labor market trends from postings alone.
# 1 Introduction
#
# >>> Split 2 ------------
# also reveals a divergence between job posting data and realized employment, urging
# caution when inferring labor market trends from postings alone.
# 1 Introduction
# The period following the public release of ChatGPT in November 2022 has seen burgeoning
# research attempting to capture the labor market and productivity eﬀects of generative AI,
# spurred by fear of potential widespread job displacement. This paper provides a timely
# empirical analysis of this evolving landscape by leveraging U.S. Current Population Survey
# ∗Stanford University;chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Tram-
# mell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.
# 1
# (CPS) data through Q1 2025. Using the GPT-4-based occupational exposure metrics from
# Eloundou et al. (2024), I examine realized employment and earnings trends to measure
# whether, and how, disruption from new AI technologies is appearing in the U.S. workforce.
#
# >>> Split 3 ------------
# Eloundou et al. (2024), I examine realized employment and earnings trends to measure
# whether, and how, disruption from new AI technologies is appearing in the U.S. workforce.
# The central ﬁnding is that the most AI-exposed set of occupations has not experienced a
# declining share of employment, though among this group there is considerable heterogeneity
# in labor market trends. Software occupations, which are estimated to have high exposure to
# generative AI, show employment gains as of the ﬁrst quarter of 2025. In contrast, customer
# service representatives, who also have high measured exposure, have experienced relative
# employment declines. More broadly, within the most exposed quartile, occupations with a
# higher share of college-educated workers have experienced faster employment growth over
# the prior four years compared to occupations with a lower college share. The results suggest
# a nuanced view of how measured AI or automation exposure aﬀect employment, with worker
#
# >>> Split 4 ------------
# the prior four years compared to occupations with a lower college share. The results suggest
# a nuanced view of how measured AI or automation exposure aﬀect employment, with worker
# characteristics such as education potentially inﬂuencing displacement from new technologies.
# While the results do not identify a causal impact of AI on labor market outcomes, they clarify
# facts about the state of the US labor market and suggest avenues for further study on how
# AI impacts workers.1
# Given growing concern over AI’s impact on early-career roles, I also examine trends for
# entry-level workers (Thompson, 2025; Raman, 2025; Allen, 2025). Employment for entry-
# level workers is volatile and cyclical, making it diﬃcult to discern trends. With more time
# and larger surveys it may become apparent whether there are sustained changes in labor
# market outcomes for entry-level workers, but so far evidence from the CPS is inconclusive.
#
# >>> Split 5 ------------
# and larger surveys it may become apparent whether there are sustained changes in labor
# market outcomes for entry-level workers, but so far evidence from the CPS is inconclusive.
# A further contribution of this paper is to highlight the divergence between employment
# and job postings. While Indeed job postings for software development show a decline from
# a peak in early 2022, CPS employment data indicate stable or even increasing employment
# through Q1 2025. The disconnect between job postings and employment also tracks with
# 1Another way to interpret the results is that current AI exposure and automation measures may do a poor
# job of predicting the true labor market impacts of AI, at least in the relatively short time period considered
# here. This contrasts with ﬁndings in prior seminal work such as Autor et al. (2003) that showed that task
# exposure to computerization strongly predicted changes in relative labor demand.
# 2

# %% [markdown]
# ### Storing documents

# %% [markdown]
# Define an embedding model

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# Define a vector store

# %% [markdown]
# In Memory Vector Store

# %%
# vector_store = InMemoryVectorStore(embeddings)

# %% [markdown]
# FAISS Vector Store

# %%
embedding_dim = len(embeddings.embed_query("hello world"))
index = faiss.IndexFlatL2(embedding_dim)

vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
document_ids = vector_store.add_documents(documents=all_splits)

print(document_ids[:3])
# Out:
# ['77b8e5a0-9768-4f73-9c72-73236a6f1821', '4535e11a-5177-4806-beff-cc6fd717ee83', '436d4671-79a1-4dc2-b9d4-273c2f33285b']

# %%
print(vector_store.get_by_ids([document_ids[30]])[0].page_content)
# Out:
# Graduates following the Great Recession,” inEducation, Skills, and Technical Change:
# Implications for Future US GDP Growth, University of Chicago Press, 149–181. 4
# Acemoglu, D., D. Autor, J. Hazell, and P. Restrepo(2022): “ArtiﬁcialIntelligence
# and Jobs: Evidence from Online Vacancies,”Journal of Labor Economics, 40, S293–S340,
# publisher: The University of Chicago Press. 2, 4
# Allen, Mike, J. V. (2025): “Behind the Curtain: Top AI CEO foresees white-collar
# bloodbath,” . 1, 4.3
# Autor, D. H., F. Levy, and R. J. Murnane(2003): “The Skill Content of Recent
# Technological Change: An Empirical Exploration*,”The Quarterly Journal of Economics,
# 118, 1279–1333. 1
# 15
# Bick, A., A. Blandin, and D. J. Deming(2024): “The Rapid Adoption of Generative
# AI,” . 4
# Bonney, K., C. Breaux, C. Buffington, E. Dinlersoz, L. Foster, N. Gold-
# schlag, J. Haltiwanger, Z. Kroff, and K. Savage(2024): “The impact of AI on
# the workforce: Tasks versus jobs?”Economics Letters, 244, 111971. 4

# %% [markdown]
# ## Step 2: Retrieval

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Similarity Search

# %% [markdown]
# Get chunck of text that are similar to a query

# %%
sims = vector_store.similarity_search(query='benefit of a genai system in after sales service ', k=4)
len(sims)
# Out:
# 4

# %%
for i, item in enumerate(sims):
    print(f"--- result #{i+1} ---")
    print("text:")
    wrapped = wrapped = textwrap.fill(item.page_content.replace("\n", " "), width=150)
    print(wrapped)

    print("text length:", len(item.page_content))
    print()
# Out:
# --- result #1 ---
# text:
# (2025) ﬁnd that access to AI assistance increases worker productivity, as measured by issues resolved per hour, by 15% on average for customer service
# representatives, with substan- tial heterogeneity across workers. Figure 2 suggests that employment in customer service representatives has declined
# since the release of ChatGPT. These ﬁndings raise the question of which occupational characteristics may inﬂuence the employment eﬀects of AI given
# some level of measured exposure. Figure 3 shows employment trends for the most exposed quartile of occupations split by whether the college share in
# the occupation is above or below the median. The results suggest employment share increases in more educated exposed occupations and employment share
# declines in less educated exposed occupations in the periods before and after the release of ChatGPT. 4.3 Labor Market Trends for Entry-Level Workers
# In recent months there has been a growing concern that AI is beginning to displace entry-
# text length: 986
#
# --- result #2 ---
# text:
# through A3 show similar results using alternative measures of AI exposure. 4.2 Software and Customer Service as Case Studies Trends in the aggregate
# data mask the divergent patterns for key high-exposure occupa- tions. This section presents two case studies—software developers and customer service
# representatives—that highlight this heterogeneity. Table 1 shows that software development occupations have some of the highest estimated exposure to
# AI, consistent with LLMs being relatively proﬁcient in writing computer code. Figure 2 shows the employment trends for the Census occupation code
# corresponding to software developers. The results suggest an 7  2021-01 2021-07 2022-01 2022-07 2023-01 2023-07 2024-01 2024-07 2025-01 Quarter 0.900
# 0.925 0.950 0.975 1.000 1.025 1.050 1.075 1.100 Normalized Employment Share Employment Share Trends by GPT Exposure Quartile Q1 Q2 Q3 Q4 2021-01
# 2021-07 2022-01 2022-07 2023-01 2023-07 2024-01 2024-07 2025-01 Quarter 0.900 0.925 0.950 0.975 1.000 1.025
# text length: 997
#
# --- result #3 ---
# text:
# Interpreters and translators Writers and authors Least Exposed Occupations Athletes and sports competitors Packaging and ﬁlling machine operators
# Paper goods machine setters and operators Roustabouts, oil and gas Bus and truck mechanics Automotive glass installers and repairers Riggers
# Electrical power-line installers Excavating machine operators Rail-track maintenance operators 4-based β metric. The plots shows the average
# employment and average real usual weekly earnings in each quarter for each quartile of AI exposure. Each series is normalized to 1 in Q4 2022,
# correponding to the time when ChatGPT was ﬁrst released. The results suggest little if any evidence of relative employment declines in the most AI-
# exposed occupations since the release of ChatGPT. Real earnings have also grown at a similar rate. Figures A1 through A3 show similar results using
# alternative measures of AI exposure. 4.2 Software and Customer Service as Case Studies
# text length: 952
#
# --- result #4 ---
# text:
# https://onlinelibrary.wiley.com/doi/pdf/10.1002/smj.3286. 2 ——— (2023): “How will Language Modelers like ChatGPT Aﬀect Occupations and Indus- tries?”
# ArXiv:2303.01157 [econ]. 2 Felten, E. W., M. Raj, and R. Seamans(2018): “A Method to Link Advances in Artiﬁcial Intelligence to Occupational
# Abilities,”AEA Papers and Proceedings, 108, 54– 57. 2 ——— (2019): “The Occupational Impact of Artiﬁcial Intelligence: Labor, Skills, and Po-
# larization,” . 2 Frank, M. R., Y.-Y. Ahn, and E. Moro(2025): “AI exposure predicts unemployment risk: A new approach to technology-driven job
# loss,”PNAS Nexus, 4, pgaf107. 4 Frey, C. B. and M. A. Osborne(2017): “The future of employment: How susceptible are jobs to
# computerisation?”Technological Forecasting and Social Change, 114, 254–280. 2 Gmyrek, P., J. Berg, and D. Bescond(2023): “Generative AI and Jobs: A
# Global Analysis of Potential Eﬀects on Job Quantity and Quality,” . 2 Gmyrek, P., J. Berg, K. Kamiński, F. Konopczyński, A. Ładna, K. Rosłaniec,
# text length: 990

# %%
sims = vector_store.similarity_search(query='employees reactions to the AI', k=4)
len(sims)
# Out:
# 4

# %%
for i, item in enumerate(sims):
    print(f"--- result #{i+1} ---")
    print("text:")
    wrapped = wrapped = textwrap.fill(item.page_content.replace("\n", " "), width=150)
    print(wrapped)

    # some useful derived info
    print("text length:", len(item.page_content))
    print()
# Out:
# --- result #1 ---
# text:
# Eloundou et al. (2024), I examine realized employment and earnings trends to measure whether, and how, disruption from new AI technologies is
# appearing in the U.S. workforce. The central ﬁnding is that the most AI-exposed set of occupations has not experienced a declining share of
# employment, though among this group there is considerable heterogeneity in labor market trends. Software occupations, which are estimated to have high
# exposure to generative AI, show employment gains as of the ﬁrst quarter of 2025. In contrast, customer service representatives, who also have high
# measured exposure, have experienced relative employment declines. More broadly, within the most exposed quartile, occupations with a higher share of
# college-educated workers have experienced faster employment growth over the prior four years compared to occupations with a lower college share. The
# results suggest a nuanced view of how measured AI or automation exposure aﬀect employment, with worker
# text length: 980
#
# --- result #2 ---
# text:
# Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang et al. (2025) ﬁnd AI exposure is correlated with longer work
# hours in the U.S.4 This paper adds additional color to this growing set of ﬁndings. In line with Humlum and Vestergaard (2025), I ﬁnd little evidence
# of an aggregate decline in employment for exposed occupations. However, in contrast to their work, I ﬁnd heterogeneity in employment trends across
# exposed occupations, with these diﬀerences correlated with features such as education. The diver- gent paths of software developers and customer
# service representatives, for example, suggest nuance in predictions of labor market changes for exposed workers.5 Finally, this work highlights an
# important methodological issue: the divergence between job postings and employment data. Recent studies have used job postings to measure shifts in
# labor demand from AI (e.g., Acemoglu et al. (2022); Hampole et al. (2025)). This paper
# text length: 974
#
# --- result #3 ---
# text:
# the prior four years compared to occupations with a lower college share. The results suggest a nuanced view of how measured AI or automation exposure
# aﬀect employment, with worker characteristics such as education potentially inﬂuencing displacement from new technologies. While the results do not
# identify a causal impact of AI on labor market outcomes, they clarify facts about the state of the US labor market and suggest avenues for further
# study on how AI impacts workers.1 Given growing concern over AI’s impact on early-career roles, I also examine trends for entry-level workers
# (Thompson, 2025; Raman, 2025; Allen, 2025). Employment for entry- level workers is volatile and cyclical, making it diﬃcult to discern trends. With
# more time and larger surveys it may become apparent whether there are sustained changes in labor market outcomes for entry-level workers, but so far
# evidence from the CPS is inconclusive.
# text length: 922
#
# --- result #4 ---
# text:
# through A3 show similar results using alternative measures of AI exposure. 4.2 Software and Customer Service as Case Studies Trends in the aggregate
# data mask the divergent patterns for key high-exposure occupa- tions. This section presents two case studies—software developers and customer service
# representatives—that highlight this heterogeneity. Table 1 shows that software development occupations have some of the highest estimated exposure to
# AI, consistent with LLMs being relatively proﬁcient in writing computer code. Figure 2 shows the employment trends for the Census occupation code
# corresponding to software developers. The results suggest an 7  2021-01 2021-07 2022-01 2022-07 2023-01 2023-07 2024-01 2024-07 2025-01 Quarter 0.900
# 0.925 0.950 0.975 1.000 1.025 1.050 1.075 1.100 Normalized Employment Share Employment Share Trends by GPT Exposure Quartile Q1 Q2 Q3 Q4 2021-01
# 2021-07 2022-01 2022-07 2023-01 2023-07 2024-01 2024-07 2025-01 Quarter 0.900 0.925 0.950 0.975 1.000 1.025
# text length: 997

# %% [markdown]
# ### Create a tool which perform the retrieval when needed

# %% [markdown]
# We will create a tool that will be used by the llm to perform a semantic search of the index before looking for an answer

# %%
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=5)
    # put all retrieved document into one single string
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# %%
retrieve_context(query='employees reactions to the AI')
# Out:
# ("Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 1536}\nContent: Eloundou et al. (2024), I examine realized employment and earnings trends to measure\nwhether, and how, disruption from new AI technologies is appearing in the U.S. workforce.\nThe central ﬁnding is that the most AI-exposed set of occupations has not experienced a\ndeclining share of employment, though among this group there is considerable heterogeneity\nin labor market trends. Software occupations, which are estimated to have high exposure to\ngenerative AI, show employment gains as of the ﬁrst quarter of 2025. In contrast, customer\nservice representatives, who also have high measured exposure, have experienced relative\nemployment declines. More broadly, within the most exposed quartile, occupations with a\nhigher share of college-educated workers have experienced faster employment growth over\nthe prior four years compared to occupations with a lower college share. The results suggest\na nuanced view of how measured AI or automation exposure aﬀect employment, with worker\n\nSource: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 6248}\nContent: Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang\net al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper\nadds additional color to this growing set of ﬁndings. In line with Humlum and Vestergaard\n(2025), I ﬁnd little evidence of an aggregate decline in employment for exposed occupations.\nHowever, in contrast to their work, I ﬁnd heterogeneity in employment trends across exposed\noccupations, with these diﬀerences correlated with features such as education. The diver-\ngent paths of software developers and customer service representatives, for example, suggest\nnuance in predictions of labor market changes for exposed workers.5\nFinally, this work highlights an important methodological issue: the divergence between\njob postings and employment data. Recent studies have used job postings to measure shifts\nin labor demand from AI (e.g., Acemoglu et al. (2022); Hampole et al. (2025)). This paper\n\nSource: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanfo ...
#  [Document(id='436d4671-79a1-4dc2-b9d4-273c2f33285b', metadata={'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 1536}, page_content='Eloundou et al. (2024), I examine realized employment and earnings trends to measure\nwhether, and how, disruption from new AI technologies is appearing in the U.S. workforce.\nThe central ﬁnding is that the most AI-exposed set of occupations has not experienced a\ndeclining share of employment, though among this group there is considerable heterogeneity\nin labor market trends. Software occupations, which are estimated to have high exposure to\ngenerative AI, show employment gains as of the ﬁrst quarter of 2025. In contrast, customer\nservice representatives, who also have high measured exposure, have experienced relative\nemployment declines. More broadly, within the most exposed quartile, occupations with a\nhigher share of college-educated workers have experienced faster employment growth over\nthe prior four years compared to occupations with a lower college share. The results suggest\na nuanced view of how measured AI or automation exposure aﬀect employment, with worker'),
#   Document(id='6e15cd10-b95b-4a7f-bc50-cfa6995b2897', metadata={'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 6248}, page_content='Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang\net al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper\nadds additional color to this growing set of ﬁndings. In line with Humlum and Vestergaard\n(2025), I ﬁnd little evidence of an aggregate decline in employment for exposed occupations.\nHowever, in contrast to their work, I ﬁnd heterogeneity in employment trends across exposed\noccupations, with these diﬀerences correlated with features such as education. The diver-\ngent paths of software developers and customer service representatives, for example, suggest\nnuance in predictions of labor market changes for exposed workers.5\nFinally, this work highlights an important methodological issue: the divergence between\njob postings and employment data. Recent studies have used job postings to measure shifts\nin labor demand from AI (e.g., Acemoglu et al. (2022); Hampole et al. (2025)). This paper'),
#   Document(id='bfb99c6f-5c97-4488-b3cc-a3afaea4501a', metadata={'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 2337}, page_content='the prior four years compared to occupations with a lower college share. The results suggest\na nuanced view of how measured AI or automation exposure aﬀect employment, with worker\ncharacteristics such as education potentially inﬂuencing displacement from new technologies.\nWhile the results do not identify a causal impact of AI on labor market outcomes, they clarify\nfacts about the state of the US labor market and suggest avenues for further study on how\nAI impacts workers.1\nGiven growing concern over AI’s impact on early-career roles, I also examine trends for\nentry-level workers (Thompson, 2025; Raman, 2025; Allen, 2025). Employment for entry-\nlevel workers is volatile and cyclical, making it diﬃcult to discern trends. With more time\nand larger surveys it may become apparent whether there are sustained changes in labor\nmarket outcomes for entry-level workers, but so far evidence from the CPS is inconclusive.'),
#   Document(id='59ea9ed5-aac5-4575-a82f-7938d013a37b', metadata={'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 13392}, page_content='through A3 show similar results using alternative measures of AI exposure.\n4.2 Software and Customer Service as Case Studies\nTrends in the aggregate data mask the divergent patterns for key high-exposure occupa-\ntions. This section presents two case studies—software developers and customer service\nrepresentatives—that highlight this heterogeneity. Table 1 shows that software development\noccupations have some of the highest estimated exposure to AI, consistent with LLMs being\nrelatively proﬁcient in writing computer code. Figure 2 shows the employment trends for\nthe Census occupation code corresponding to software developers. The results suggest an\n7\n\x0c2021-01 2021-07 2022-01 2022-07 2023-01 2023-07 2024-01 2024-07 2025-01\nQuarter\n0.900\n0.925\n0.950\n0.975\n1.000\n1.025\n1.050\n1.075\n1.100\nNormalized Employment Share\nEmployment Share Trends by GPT Exposure Quartile\nQ1\nQ2\nQ3\nQ4\n2021-01 2021-07 2022-01 2022-07 2023-01 2023-07 2024-01 2024-07 2025-01\nQuarter\n0.900\n0.925\n0.950\n0.975\n1.000\n1.025'),
#   Document(id='7cac3d8a-e5d4-4554-bbed-d93136c81872', metadata={'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 15707}, page_content='(2025) ﬁnd that access to AI assistance increases worker productivity, as measured by issues\nresolved per hour, by 15% on average for customer service representatives, with substan-\ntial heterogeneity across workers. Figure 2 suggests that employment in customer service\nrepresentatives has declined since the release of ChatGPT.\nThese ﬁndings raise the question of which occupational characteristics may inﬂuence the\nemployment eﬀects of AI given some level of measured exposure. Figure 3 shows employment\ntrends for the most exposed quartile of occupations split by whether the college share in the\noccupation is above or below the median. The results suggest employment share increases in\nmore educated exposed occupations and employment share declines in less educated exposed\noccupations in the periods before and after the release of ChatGPT.\n4.3 Labor Market Trends for Entry-Level Workers\nIn recent months there has been a growing concern that AI is beginning to displace entry-')])

# %%
from langchain.tools import tool

@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=5)
    # put all retrieved document into one single string
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# %% [markdown]
# ### Create an agent that will use this tool

# %% [markdown]
# We create an agent. We will define:
# - the model used by the agent (`ChatOpenAI` (abstraction from LangChain))
# - the tool available (`retrieve_context`]
# - a system prompt

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI

model = ChatOpenAI(temperature=0, model="gpt-4.1-mini")
tools = [retrieve_context]

system_prompt = (
    "You have access to a tool that retrieves context from a set of files. "
    "Use the tool to help answer user queries."
)

agent = create_agent(model, tools, system_prompt=system_prompt)

# %% [markdown]
# Now we can use the agent with specific prompts.
#
# We will visualise all messages from the agent, including all intermediate exchanges.

# %%
query = (
    "What are the key findings in this paper"
)

for event in agent.stream(
    input={"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What are the key findings in this paper
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_qGDXKg6Nvag5bw7DDo2cLTf6)
#  Call ID: call_qGDXKg6Nvag5bw7DDo2cLTf6
#   Args:
#     query: key findings
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 5464}
# Content: While these studies identify potential disruption, this paper’s contribution is to use broad,
# representative U.S. survey data (the CPS) to provide one of the earliest empirical snapshots
# of realized employment changes in the post-ChatGPT era. This complements studies that
# ﬁnd signiﬁcant eﬀects but in more speciﬁc settings, such as on online freelance platforms
# (Hui et al., 2023) or within individual ﬁrms (Brynjolfsson et al., 2025; Dillon et al., 2025).3
# Second, this paper contributes to the growing body of work using economy-wide data to
# 2All code is posted online athttps://github.com/chandarb/CPS_tracker.
# 3See also Noy and Zhang (2023); Peng et al. (2023); Dell’Acqua et al. (2023).
# 3
# measure AI’s impact. Recent ﬁndings have been varied. Humlum and Vestergaard (2025) use
# Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang
# et al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 3082}
# Content: and larger surveys it may become apparent whether there are sustained changes in labor
# market outcomes for entry-level workers, but so far evidence from the CPS is inconclusive.
# A further contribution of this paper is to highlight the divergence between employment
# and job postings. While Indeed job postings for software development show a decline from
# a peak in early 2022, CPS employment data indicate stable or even increasing employment
# through Q1 2025. The disconnect between job postings and employment also tracks with
# 1Another way to interpret the results is that current AI exposure and automation measures may do a poor
# job of predicting the true labor market impacts of AI, at least in the relatively short time period considered
# here. This contrasts with ﬁndings in prior seminal work such as Autor et al. (2003) that showed that task
# exposure to computerization strongly predicted changes in relative labor demand.
# 2
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 4666}
# Content: for future work using larger-scale administrative or internal Census data to further probe
# the mechanisms behind these divergent outcomes.2
# 2 Related Literature
# This paper engages with three active areas of research on the labor market eﬀects of arti-
# ﬁcial intelligence. First, it builds on literature that measures AI’spotential exposure. A
# series of inﬂuential papers established methodologies for estimating which occupations were
# susceptible to automation (Frey and Osborne, 2017; Brynjolfsson et al., 2018; Felten et al.,
# 2018, 2019; Webb, 2019; Felten et al., 2021). More recently, work such as Eloundou et al.
# (2024); Felten et al. (2023); Gmyrek et al. (2023), and Gmyrek et al. (2025) adapted this
# approach for Generative AI, forming the basis for exposure metrics used in this analysis.
# While these studies identify potential disruption, this paper’s contribution is to use broad,
# representative U.S. survey data (the CPS) to provide one of the earliest empirical snapshots
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 3824}
# Content: here. This contrasts with ﬁndings in prior seminal work such as Autor et al. (2003) that showed that task
# exposure to computerization strongly predicted changes in relative labor demand.
# 2
# a relatively stable US national unemployment rate and labor force participation rate over
# the same period. These ﬁndings urge caution in interpreting labor market trends from job
# postings alone.
# Because the CPS is released monthly and is publicly accessible, the method in this paper
# can be used to track changes in occupational employment on an ongoing and transparent
# basis. While the CPS’s sample size limits statistical power for granular groups like entry-level
# workers, its strength lies in providing a consistent, high-frequency view of the entire U.S.
# labor market. This paper thus clariﬁes the current state of facts and provides a foundation
# for future work using larger-scale administrative or internal Census data to further probe
# the mechanisms behind these divergent outcomes.2
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 6248}
# Content: Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang
# et al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper
# adds additional color to this growing set of ﬁndings. In line with Humlum and Vestergaard
# (2025), I ﬁnd little evidence of an aggregate decline in employment for exposed occupations.
# However, in contrast to their work, I ﬁnd heterogeneity in employment trends across exposed
# occupations, with these diﬀerences correlated with features such as education. The diver-
# gent paths of software developers and customer service representatives, for example, suggest
# nuance in predictions of labor market changes for exposed workers.5
# Finally, this work highlights an important methodological issue: the divergence between
# job postings and employment data. Recent studies have used job postings to measure shifts
# in labor demand from AI (e.g., Acemoglu et al. (2022); Hampole et al. (2025)). This paper
# ================================== Ai Message ==================================
#
# The key findings of the paper "Tracking Employment Changes in AI-Exposed Jobs" by Bharat Chandar are:
#
# 1. The paper provides one of the earliest empirical snapshots of realized employment changes in the post-ChatGPT era using broad, representative U.S. survey data (the CPS).
#
# 2. It complements other studies that find significant AI effects in more specific settings, such as online freelance platforms or within individual firms.
#
# 3. The paper finds little evidence of an aggregate decline in employment for AI-exposed occupations, consistent with some recent studies using administrative data.
#
# 4. There is heterogeneity in employment trends across AI-exposed occupations, with differences correlated with factors like education. For example, software developers and customer service representatives show divergent employment paths.
#
# 5. The paper highlights a divergence between job postings and actual employment data. While job postings for software development declined from a peak in early 2022, CPS employment data indicate stable or even increasing employment through Q1 2025.
#
# 6. The disconnect between job postings and employment aligns with stable U.S. national unemployment and labor force participation rates over the same period, suggesting caution in interpreting labor market trends from job postings alone.
#
# 7. The CPS data, released monthly and publicly accessible, offers a consistent, high-frequency view of the entire U.S. labor market, useful for ongoing tracking of occupational employment changes.
#
# 8. The paper calls for future work using larger-scale administrative or internal Census data to further investigate the mechanisms behind these divergent outcomes.
#
# Overall, the study provides nuanced insights into the labor market impacts of AI exposure, showing no broad employment declines but varied effects across occupations and a notable gap between job postings and actual employment.

# %% [markdown]
# Let's ask another question about the document.

# %%
query = (
    "Wich experiments were done and described in this paper\n\n"
    "Once you have the list of experiments, look up for more information for each experiment"
)

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Wich experiments were done and described in this paper
#
# Once you have the list of experiments, look up for more information for each experiment
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_zevy6UC0WBRq1OyumgctHeex)
#  Call ID: call_zevy6UC0WBRq1OyumgctHeex
#   Args:
#     query: experiments described in the paper
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 4666}
# Content: for future work using larger-scale administrative or internal Census data to further probe
# the mechanisms behind these divergent outcomes.2
# 2 Related Literature
# This paper engages with three active areas of research on the labor market eﬀects of arti-
# ﬁcial intelligence. First, it builds on literature that measures AI’spotential exposure. A
# series of inﬂuential papers established methodologies for estimating which occupations were
# susceptible to automation (Frey and Osborne, 2017; Brynjolfsson et al., 2018; Felten et al.,
# 2018, 2019; Webb, 2019; Felten et al., 2021). More recently, work such as Eloundou et al.
# (2024); Felten et al. (2023); Gmyrek et al. (2023), and Gmyrek et al. (2025) adapted this
# approach for Generative AI, forming the basis for exposure metrics used in this analysis.
# While these studies identify potential disruption, this paper’s contribution is to use broad,
# representative U.S. survey data (the CPS) to provide one of the earliest empirical snapshots
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 7845}
# Content: et al. (2025); Chen et al. (2025); Hampole et al. (2025). The Federal Reserve Bank of New York tracks
# employment by college major using the American Community Survey (ACS), as documented in Abel and
# Deitz (2017). While the ACS has rich sociodemographic and economic information, it is released annually
# and with a time lag. As of Q2 2025 the latest ACS data is from 2023, in the initial year of LLM adoption.
# 5Another closely related paper is Deming et al. (2025), which combines data from the decennial Census,
# American Community Survey, and CPS to track labor market changes over 120 years. This paper comple-
# ments their work by directly associating employment changes with measures of AI exposure and by tracking
# labor market trends speciﬁcally over the post-ChatGPT time period.
# 4
# 3 Methods and Data Collection
# 3.1 Data on AI Exposure
# I use the occupation-level AI exposure estimates from Eloundou et al. (2024). The authors
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 5464}
# Content: While these studies identify potential disruption, this paper’s contribution is to use broad,
# representative U.S. survey data (the CPS) to provide one of the earliest empirical snapshots
# of realized employment changes in the post-ChatGPT era. This complements studies that
# ﬁnd signiﬁcant eﬀects but in more speciﬁc settings, such as on online freelance platforms
# (Hui et al., 2023) or within individual ﬁrms (Brynjolfsson et al., 2025; Dillon et al., 2025).3
# Second, this paper contributes to the growing body of work using economy-wide data to
# 2All code is posted online athttps://github.com/chandarb/CPS_tracker.
# 3See also Noy and Zhang (2023); Peng et al. (2023); Dell’Acqua et al. (2023).
# 3
# measure AI’s impact. Recent ﬁndings have been varied. Humlum and Vestergaard (2025) use
# Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang
# et al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 8629}
# Content: 4
# 3 Methods and Data Collection
# 3.1 Data on AI Exposure
# I use the occupation-level AI exposure estimates from Eloundou et al. (2024). The authors
# estimate AI exposure based on O*NET task and detailed work activity (DWA) descriptions.
# I use their exposure measures that leverage GPT-4 to classify all tasks and DWAs based on
# the whether using an LLM reduces the time it takes to complete the task by at least 50%.
# I aggregate from tasks to occupations by equally weighting exposure across tasks within an
# occupation.
# Eloundou et al. (2024) report a variety of diﬀerent exposure measures based on this
# approaches. Each measure varies assumed capabilities of LLMs, namely whether they can
# reduce the time to complete a task on their own or in conjunction with additional software.
# I focus on their GPT-4-basedβ measure for most of the analysis, though I show robustness
# to alternative measures for certain results.
# 3.2 Data on Employment and Earnings
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 6248}
# Content: Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang
# et al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper
# adds additional color to this growing set of ﬁndings. In line with Humlum and Vestergaard
# (2025), I ﬁnd little evidence of an aggregate decline in employment for exposed occupations.
# However, in contrast to their work, I ﬁnd heterogeneity in employment trends across exposed
# occupations, with these diﬀerences correlated with features such as education. The diver-
# gent paths of software developers and customer service representatives, for example, suggest
# nuance in predictions of labor market changes for exposed workers.5
# Finally, this work highlights an important methodological issue: the divergence between
# job postings and employment data. Recent studies have used job postings to measure shifts
# in labor demand from AI (e.g., Acemoglu et al. (2022); Hampole et al. (2025)). This paper
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_WUUQi1PoNyB9SoECDQkKIoFJ)
#  Call ID: call_WUUQi1PoNyB9SoECDQkKIoFJ
#   Args:
#     query: experiments or empirical analyses described in the paper Tracking Employment Changes in AI-Exposed Jobs
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 4666}
# Content: for future work using larger-scale administrative or internal Census data to further probe
# the mechanisms behind these divergent outcomes.2
# 2 Related Literature
# This paper engages with three active areas of research on the labor market eﬀects of arti-
# ﬁcial intelligence. First, it builds on literature that measures AI’spotential exposure. A
# series of inﬂuential papers established methodologies for estimating which occupations were
# susceptible to automation (Frey and Osborne, 2017; Brynjolfsson et al., 2018; Felten et al.,
# 2018, 2019; Webb, 2019; Felten et al., 2021). More recently, work such as Eloundou et al.
# (2024); Felten et al. (2023); Gmyrek et al. (2023), and Gmyrek et al. (2025) adapted this
# approach for Generative AI, forming the basis for exposure metrics used in this analysis.
# While these studies identify potential disruption, this paper’s contribution is to use broad,
# representative U.S. survey data (the CPS) to provide one of the earliest empirical snapshots
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 6248}
# Content: Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang
# et al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper
# adds additional color to this growing set of ﬁndings. In line with Humlum and Vestergaard
# (2025), I ﬁnd little evidence of an aggregate decline in employment for exposed occupations.
# However, in contrast to their work, I ﬁnd heterogeneity in employment trends across exposed
# occupations, with these diﬀerences correlated with features such as education. The diver-
# gent paths of software developers and customer service representatives, for example, suggest
# nuance in predictions of labor market changes for exposed workers.5
# Finally, this work highlights an important methodological issue: the divergence between
# job postings and employment data. Recent studies have used job postings to measure shifts
# in labor demand from AI (e.g., Acemoglu et al. (2022); Hampole et al. (2025)). This paper
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 5464}
# Content: While these studies identify potential disruption, this paper’s contribution is to use broad,
# representative U.S. survey data (the CPS) to provide one of the earliest empirical snapshots
# of realized employment changes in the post-ChatGPT era. This complements studies that
# ﬁnd signiﬁcant eﬀects but in more speciﬁc settings, such as on online freelance platforms
# (Hui et al., 2023) or within individual ﬁrms (Brynjolfsson et al., 2025; Dillon et al., 2025).3
# Second, this paper contributes to the growing body of work using economy-wide data to
# 2All code is posted online athttps://github.com/chandarb/CPS_tracker.
# 3See also Noy and Zhang (2023); Peng et al. (2023); Dell’Acqua et al. (2023).
# 3
# measure AI’s impact. Recent ﬁndings have been varied. Humlum and Vestergaard (2025) use
# Danish administrative data to ﬁnd minimal eﬀects on earnings or hours worked, while Jiang
# et al. (2025) ﬁnd AI exposure is correlated with longer work hours in the U.S.4 This paper
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 0}
# Content: Tracking Employment Changes in AI-Exposed Jobs
# Bharat Chandar∗
# August 1, 2025
# Abstract
# This paper examines labor market trends for occupations exposed to Generative AI
# using US Current Population Survey (CPS) data from the post-ChatGPT era (Q4 2022
# - Q1 2025). Contrary to displacement fears, occupations most exposed to AI on average
# show no substantial diﬀerence in employment or earnings growth compared to the
# least exposed. However, this aggregate trend masks heterogeneity across occupations.
# Within the most exposed quartile, occupations with a higher share of college-educated
# workers, such as software development, have experienced robust employment growth,
# while those with a lower share, like customer service, have seen declines. The analysis
# also reveals a divergence between job posting data and realized employment, urging
# caution when inferring labor market trends from postings alone.
# 1 Introduction
#
# Source: {'producer': 'pdfTeX-1.40.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-01T12:04:28-07:00', 'author': 'Bharat ChandarStanford University; chandarb@stanford.edu. I thank Erik Bynjolfsson, Basil Halperin, Philip Trammell, Luca Vendraminelli, Ruyu Chen, and Tom Mitchell for helpful comments.', 'title': 'Tracking Employment Changes in AI-Exposed Jobs', 'subject': '', 'keywords': '', 'moddate': '2025-08-01T12:04:28-07:00', 'trapped': '/False', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2021) kpathsea version 6.3.3', 'source': 'data/Stanford - Tracking Employment Changes in AI-Exposed Jobs.pdf', 'total_pages': 23, 'start_index': 1536}
# Content: Eloundou et al. (2024), I examine realized employment and earnings trends to measure
# whether, and how, disruption from new AI technologies is appearing in the U.S. workforce.
# The central ﬁnding is that the most AI-exposed set of occupations has not experienced a
# declining share of employment, though among this group there is considerable heterogeneity
# in labor market trends. Software occupations, which are estimated to have high exposure to
# generative AI, show employment gains as of the ﬁrst quarter of 2025. In contrast, customer
# service representatives, who also have high measured exposure, have experienced relative
# employment declines. More broadly, within the most exposed quartile, occupations with a
# higher share of college-educated workers have experienced faster employment growth over
# the prior four years compared to occupations with a lower college share. The results suggest
# a nuanced view of how measured AI or automation exposure aﬀect employment, with worker
# ================================== Ai Message ==================================
#
# The paper "Tracking Employment Changes in AI-Exposed Jobs" by Bharat Chandar describes empirical analyses using U.S. labor market data to study the impact of Generative AI exposure on employment and earnings. The key empirical analyses or "experiments" described in the paper include:
#
# 1. Using occupation-level AI exposure estimates from Eloundou et al. (2024), which classify tasks based on whether using a large language model (LLM) like GPT-4 reduces task completion time by at least 50%. These exposure measures are aggregated to the occupation level.
#
# 2. Analyzing broad, representative U.S. survey data from the Current Population Survey (CPS) covering the post-ChatGPT era (Q4 2022 - Q1 2025) to provide an empirical snapshot of realized employment and earnings changes in AI-exposed occupations.
#
# 3. Comparing employment and earnings growth trends between occupations with high AI exposure and those with low exposure, finding no substantial aggregate difference but significant heterogeneity within the most exposed quartile.
#
# 4. Examining heterogeneity by education level within AI-exposed occupations, showing that occupations with a higher share of college-educated workers (e.g., software developers) experienced employment growth, while those with a lower share (e.g., customer service representatives) saw declines.
#
# 5. Highlighting the divergence between job posting data and realized employment data, cautioning against inferring labor market trends solely from job postings.
#
# These analyses use occupation-level AI exposure metrics combined with labor market data from CPS and other sources to track employment and earnings changes in the context of Generative AI adoption.
#
# Would you like me to provide more detailed information on any specific analysis or aspect of the experiments?
